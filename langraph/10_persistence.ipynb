# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()

llm = ChatOpenAI()

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': "Why did the pizza go to the therapist? Because it had too many toppings and couldn't find itself!",
#  'explanation': 'This joke is a play on words and uses a common therapy-related theme. In the joke, the pizza is portrayed as a person seeking therapy because it has too many toppings and is feeling lost or confused. The punchline suggests that the pizza is struggling to "find itself" and needs help to sort out its issues. Overall, the humor comes from the absurdity of a pizza seeking therapy and the clever twist on the concept of self-discovery.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': "Why did the pizza go to the therapist? Because it had too many toppings and couldn't find itself!", 'explanation': 'This joke is a play on words and uses a common therapy-related theme. In the joke, the pizza is portrayed as a person seeking therapy because it has too many toppings and is feeling lost or confused. The punchline suggests that the pizza is struggling to "find itself" and needs help to sort out its issues. Overall, the humor comes from the absurdity of a pizza seeking therapy and the clever twist on the concept of self-discovery.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3cc-c7b7-6260-8002-b0d6ff387d0d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-23T19:50:34.455861+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3cc-b9dd-69c8-8001-f1fe3f678150'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': "Why did the pizza go to the therapist? Because it had too many toppings and couldn't find itself!", 'explanation': 'This joke is a play on words and uses a common therapy-related theme. In the joke, the pizza is portrayed as a person seeking therapy because it has too many toppings and is feeling lost or confused. The punchline suggests that the pizza is struggling to "find itself" and needs help to sort out its issues. Overall, the humor comes from the absurdity of a pizza seeking therapy and the clever twist on the concept of self-discovery.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3cc-c7b7-6260-8002-b0d6ff387d0d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-23T19:50:34.455861+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3cc-b9dd-69c8-8001-f1fe3f678150'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': "Why did the pizza go to the therapist? Because it had too many toppings and couldn't find itself!"}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3cc-b9dd-69c8-8001-f1fe3f678150'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-06-23T19:50:33.003606+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3cc-8292-6626-8000-94b7b9445087'}}, tasks=(PregelTask(id='ae962fd1-7d86-810c-a473-8cdba9cd5273', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words and uses a common therapy-related theme. In the joke, the pizza is portrayed as a person seeking therapy because it has too many toppings and is feeling lost or confused. The punchline suggests that the pizza is struggling to "find itself" and needs help to sort out its issues. Overall, the humor comes from the absurdity of a pizza seeking therapy and the clever twist on the concept of self-discovery.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3cc-8292-6626-8000-94b7b9445087'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-23T19:50:27.205670+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3cc-8282-635c-bfff-c0f87b31b466'}}, tasks=(PregelTask(id='255dfe15-6545-4830-7218-8970c3296d84', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Why did the pizza go to the therapist? Because it had too many toppings and couldn't find itself!"}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3cc-8282-635c-bfff-c0f87b31b466'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-23T19:50:27.198917+00:00', parent_config=None, tasks=(PregelTask(id='0bf4d42b-d30a-ba5b-c224-513b330298de', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the pasta go to the party? \nBecause it heard it was going to be a spaghetti-ni!',
#  'explanation': 'This joke plays on the similarity in sound between "spaghetti" and "spaghetti-ni," which sounds like "spaghetti" with the addition of "-ni" at the end. The pasta went to the party because it heard it was going to be a "spaghetti-ni," which is a play on words and a clever way to incorporate pasta into a pun. The humor comes from the unexpected and silly nature of the wordplay.'}

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the pasta go to the party? \nBecause it heard it was going to be a spaghetti-ni!', 'explanation': 'This joke plays on the similarity in sound between "spaghetti" and "spaghetti-ni," which sounds like "spaghetti" with the addition of "-ni" at the end. The pasta went to the party because it heard it was going to be a "spaghetti-ni," which is a play on words and a clever way to incorporate pasta into a pun. The humor comes from the unexpected and silly nature of the wordplay.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3ce-9080-6222-8002-31c6cc813073'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-23T19:51:22.353271+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3ce-80a3-6f2a-8001-61c17cbb6359'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the pasta go to the party? \nBecause it heard it was going to be a spaghetti-ni!', 'explanation': 'This joke plays on the similarity in sound between "spaghetti" and "spaghetti-ni," which sounds like "spaghetti" with the addition of "-ni" at the end. The pasta went to the party because it heard it was going to be a "spaghetti-ni," which is a play on words and a clever way to incorporate pasta into a pun. The humor comes from the unexpected and silly nature of the wordplay.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3ce-9080-6222-8002-31c6cc813073'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-23T19:51:22.353271+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3ce-80a3-6f2a-8001-61c17cbb6359'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the pasta go to the party? \nBecause it heard it was going to be a spaghetti-ni!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3ce-80a3-6f2a-8001-61c17cbb6359'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-06-23T19:51:20.690172+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3ce-70bd-6fd4-8000-408bd843391f'}}, tasks=(PregelTask(id='698ba0d6-f1da-6895-7dd5-cc3b58152766', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke plays on the similarity in sound between "spaghetti" and "spaghetti-ni," which sounds like "spaghetti" with the addition of "-ni" at the end. The pasta went to the party because it heard it was going to be a "spaghetti-ni," which is a play on words and a clever way to incorporate pasta into a pun. The humor comes from the unexpected and silly nature of the wordplay.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3ce-70bd-6fd4-8000-408bd843391f'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-23T19:51:19.023185+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3ce-70af-613c-bfff-3c65f65efceb'}}, tasks=(PregelTask(id='28bd305e-bdd3-63f2-41e7-d290561dcc79', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pasta go to the party? \nBecause it heard it was going to be a spaghetti-ni!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f16f3ce-70af-613c-bfff-3c65f65efceb'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-23T19:51:19.017076+00:00', parent_config=None, tasks=(PregelTask(id='ed48e4ca-3887-8b48-0fed-793dd05a79fd', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pasta'}),), interrupts=())]
